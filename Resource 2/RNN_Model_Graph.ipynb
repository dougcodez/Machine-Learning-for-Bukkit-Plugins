# %%
import matplotlib.pyplot as plt

# Data
data = {
    "Your account has been suspended. Click here to restore access": 0.981,
    "Your acc0unt has been suspended. Click here to restore accezzs": 0.993,
    "Your acc0unt has been suspended. Click here to restore aces": 0.868,
    "Get rich quick with this amazing opportunity!": 0.983,
    "get rich quick with this amazing opportunity!": 0.987,
    "get rich quick with this amazing op": 0.959,
    "Congratulations! You have been selected to receive a free gift.": 0.999,
    "Congratulations! You have been selected to receive a ee gift.": 0.998,
    "Congratulations! You have been selected to rceive a ee gift.": 0.993
}

# Create lists for x and y values
x_values = list(range(1, len(data)+1))
y_values = list(data.values())

# Create figure and axis objects
fig, ax = plt.subplots()

# Add data to plot
ax.plot(x_values, y_values, marker='o', color='blue')

# Add x-axis labels
ax.set_xticks(x_values)
ax.set_xticklabels(list(data.keys()), rotation=90)

# Add y-axis label
ax.set_ylabel("Prediction")
ax.set_xlabel("Sentence")
# Add title
ax.set_title("Spam Prediction")
plt.ylim(0, 1)
plt.grid()
# Display plot
plt.show()
